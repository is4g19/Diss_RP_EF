# %%
import numpy as np
import pandas as pd #to read files or work with dataframes
import yfinance as yf
import datetime as datetime #to specify start and end dates
import matplotlib.pyplot as plt #to visualize
from matplotlib import style
import pandas_datareader as dr #to collect data
from pandas_datareader import data
import cvxpy as cp
import cvxopt as opt
from cvxopt import blas, solvers
import scipy.optimize as sco

# %matplotlib inline

# %%
#Parameter set up:
n_portfolios = 5000
n_days = 252
assets = ['ETH-GBP', 'AHT.L', 'PFD.L', 'ENT.L', 'SMT.L', 'AAL.L', 'SPX.L', 'LUCE.L', 'DPLM.L', 'GSK.L', 'BP.L', 'SCT.L', 'BLND.L', 'MGGT.L', 'FUTR.L', 'CRDA.L', 'AAF.L', 'WOSG.L', 'KAPE.L', 'INDV.L', 'FAN.L', 'NFC.L', 'SAFE.L', 'MMH.L', 'CWR.L', 'XTR.L', 'BEZ.L', 'JD.L', 'NANO.L', 'BARC.L', 'AEP.L', 'GTLY.L', 'BIFF.L']
assets.sort()
start_date = '2020-01-01'
end_date = '2022-04-25'

n_assets = len(assets)

# %%
#Downloading stockprices from Yahoo Finance:
prices = yf.download(assets, start=start_date, end=end_date, adjusted=True)
# Out:
# [*********************100%***********************]  33 of 33 completed

# %%
#Calculation of Annualised Average Returns and the corresponding Standard Deviation:
returns = prices['Adj Close'].pct_change().dropna()
returns
# Out:
#                AAF.L     AAL.L     AEP.L     AHT.L    BARC.L     BEZ.L  \
# Date
# 2020-01-03 -0.003807 -0.007039 -0.032258 -0.006250 -0.010259 -0.010610
# 2020-01-04  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-01-05  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-01-06 -0.000637 -0.018980  0.035088  0.007966 -0.012657 -0.023235
# 2020-01-07  0.010835  0.006993 -0.022034 -0.002496  0.011935 -0.000915
# ...              ...       ...       ...       ...       ...       ...
# 2022-04-20 -0.011379 -0.028761  0.000000  0.040070  0.021826  0.028963
# 2022-04-21 -0.007447 -0.088341 -0.025918  0.008585  0.007926  0.022222
# 2022-04-22 -0.004775 -0.059391 -0.104213 -0.036952 -0.022391 -0.019324
# 2022-04-23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2022-04-24  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#               BIFF.L    BLND.L      BP.L    CRDA.L  ...     MMH.L    NANO.L  \
# Date                                                ...
# 2020-01-03 -0.003711  0.002547  0.027451 -0.002941  ...  0.003247  0.007394
# 2020-01-04  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2020-01-05  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2020-01-06 -0.024209 -0.023500  0.020342  0.001967  ...  0.000000  0.012844
# 2020-01-07 -0.009542  0.005854 -0.010514 -0.000981  ...  0.000000 -0.057971
# ...              ...       ...       ...       ...  ...       ...       ...
# 2022-04-20 -0.007665 -0.000390  0.000249  0.017525  ...  0.000000  0.015576
# 2022-04-21  0.008318  0.023428  0.004986  0.017223  ...  0.000000 -0.003067
# 2022-04-22 -0.008839 -0.014498 -0.024805 -0.003647  ...  0.000000 -0.027692
# 2022-04-23  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2022-04-24  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
#
#                NFC.L     PFD.L    SAFE.L     SCT.L     SMT.L     SPX.L  \
# Date
# 2020-01-03  0.015038 -0.002628 -0.003077 -0.011686  0.000853 -0.002212
# 2020-01-04  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-01-05  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-01-06  0.003704  0.001318 -0.013580 -0.025338 -0.009378 -0.006652
# 2020-01-07 -0.003690 -0.019737 -0.012516  0.016464  0.010327 -0.001116
# ...              ...       ...       ...       ...       ...       ...
# 2022-04-20  0.035115  0.000000 -0.001514  0.006012 -0.005320  0.012034
# 2022-04-21  0.005900 -0.010292  0.003791 -0.001328 -0.002995  0.008323
# 2022-04-22 -0.023460  0.010399 -0.012840 -0.007314 -0.025751 -0.026336
# 2022-04-23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2022-04-24  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#               WOSG.L     XTR.L
# Date
# 2020-01-03  0.000000  0.000000
# 2020-01-04  0.000000  0.000000
# 2020-01-05  0.000000  0.000000
# 2020-01-06 -0.037436  0.000000
# 2020-01-07  0.022376  0.000000
# ...              ...       ...
# 2022-04-20  0.036380  0.000000
# 2022-04-21 -0.007705 -0.014925
# 2022-04-22 -0.036238  0.000000
# 2022-04-23  0.000000  0.000000
# 2022-04-24  0.000000  0.000000
#
# [843 rows x 33 columns]

# %%
avg_returns = returns.mean()* n_days
avg_returns
# Out:
# AAF.L      0.347499
# AAL.L      0.236640
# AEP.L      0.160531
# AHT.L      0.271369
# BARC.L     0.028847
# BEZ.L     -0.024352
# BIFF.L     0.116559
# BLND.L     0.013267
# BP.L       0.065860
# CRDA.L     0.154017
# CWR.L      0.464280
# DPLM.L     0.155231
# ENT.L      0.255441
# ETH-GBP    1.279780
# FAN.L      0.242291
# FUTR.L     0.276193
# GSK.L      0.048683
# GTLY.L     0.084838
# INDV.L     0.760555
# JD.L       0.048806
# KAPE.L     0.307940
# LUCE.L     0.272762
# MGGT.L     0.214937
# MMH.L      0.366032
# NANO.L     0.518589
# NFC.L      0.377674
# PFD.L      0.410411
# SAFE.L     0.195423
# SCT.L      0.111542
# SMT.L      0.183615
# SPX.L      0.129015
# WOSG.L     0.424114
# XTR.L      0.994456
# dtype: float64

# %%
cov_mat = returns.cov() * n_days
cov_mat
# Out:
#             AAF.L     AAL.L     AEP.L     AHT.L    BARC.L     BEZ.L    BIFF.L  \
# AAF.L    0.278321  0.062853  0.056867  0.071069  0.083516  0.071002  0.021964
# AAL.L    0.062853  0.152670  0.031074  0.073907  0.092004  0.055162  0.027351
# AEP.L    0.056867  0.031074  0.132364  0.025365  0.039232  0.027449  0.010758
# AHT.L    0.071069  0.073907  0.025365  0.132076  0.081119  0.042819  0.025682
# BARC.L   0.083516  0.092004  0.039232  0.081119  0.151199  0.066871  0.035147
# BEZ.L    0.071002  0.055162  0.027449  0.042819  0.066871  0.125133  0.017863
# BIFF.L   0.021964  0.027351  0.010758  0.025682  0.035147  0.017863  0.096538
# BLND.L   0.051249  0.058625  0.021787  0.050671  0.085679  0.056452  0.029823
# BP.L     0.080513  0.092387  0.038050  0.065175  0.092556  0.045818  0.019193
# CRDA.L   0.024885  0.018712  0.011925  0.032772  0.014854  0.013588  0.018543
# CWR.L    0.071815  0.078458  0.030866  0.101866  0.078325  0.042574  0.029253
# DPLM.L   0.044146  0.036247  0.021023  0.051527  0.034638  0.029561  0.025608
# ENT.L    0.074071  0.072946  0.034449  0.071499  0.077356  0.047746  0.020144
# ETH-GBP  0.053090  0.059587  0.018904  0.045620  0.048454  0.016255  0.025482
# FAN.L    0.028352  0.025198  0.007815  0.032508  0.036406  0.020743  0.025002
# FUTR.L   0.084630  0.063809  0.026694  0.083500  0.069413  0.061544  0.032166
# GSK.L    0.028979  0.022877  0.012987  0.025023  0.021396  0.014602  0.011099
# GTLY.L   0.014763  0.024127  0.011700  0.023451  0.025944  0.018023  0.017848
# INDV.L   0.066142  0.025924  0.032456  0.027497  0.034336  0.029338  0.009469
# JD.L     0.083471  0.070809  0.037773  0.086834  0.094292  0.059455  0.022587
# KAPE.L   0.046297  0.038095  0.029944  0.044071  0.048124  0.024177  0.020885
# LUCE.L   0.096437  0.063144  0.022306  0.072678  0.068833  0.045745  0.021547
# MGGT.L   0.094049  0.094690  0.019399  0.092446  0.119061  0.074355  0.029276
# MMH.L    0.020014  0.012183  0.005561  0.013502  0.015237  0.012586  0.005624
# NANO.L   0.047603  0.037758  0.023068  0.037010  0.040124  0.037452  0.005978
# NFC.L    0.022380  0.033288  0.029703  0.043489  0.045049  0.023588  0.013181
# PFD.L    0.045525  0.024269  0.017173  0.026894  0.031390  0.018406  0.010282
# SAFE.L   0.039452  0.032425  0.017179  0.037140  0.037841  0.033026  0.011312
# SCT.L    0.028158  0.030830  0.011311  0.033753  0.026437  0.026156  0.017783
# SMT.L    0.050168  0.055661  0.022843  0.067100  0.048661  0.038395  0.026034
# SPX.L    0.023748  0.035256  0.011896  0.042745  0.023988  0.021909  0.020683
# WOSG.L   0.051509  0.043820  0.014557  0.052127  0.067279  0.048266  0.027405
# XTR.L    0.031638  0.019655  0.013901  0.027715  0.036363  0.006558  0.010046
#
#            BLND.L      BP.L    CRDA.L  ...     MMH.L    NANO.L     NFC.L  \
# AAF.L    0.051249  0.080513  0.024885  ...  0.020014  0.047603  0.022380
# AAL.L    0.058625  0.092387  0.018712  ...  0.012183  0.037758  0.033288
# AEP.L    0.021787  0.038050  0.011925  ...  0.005561  0.023068  0.029703
# AHT.L    0.050671  0.065175  0.032772  ...  0.013502  0.037010  0.043489
# BARC.L   0.085679  0.092556  0.014854  ...  0.015237  0.040124  0.045049
# BEZ.L    0.056452  0.045818  0.013588  ...  0.012586  0.037452  0.023588
# BIFF.L   0.029823  0.019193  0.018543  ...  0.005624  0.005978  0.013181
# BLND.L   0.110172  0.062407  0.010146  ...  0.009850  0.018097  0.031331
# BP.L     0.062407  0.143676  0.010068  ...  0.009740  0.030401  0.037430
# CRDA.L   0.010146  0.010068  0.047531  ...  0.004231  0.017528  0.015258
# CWR.L    0.044209  0.047471  0.045045  ...  0.022671  0.046257  0.050073
# DPLM.L   0.026479  0.024433  0.027236  ...  0.014010  0.034082  0.026342
# ENT.L    0.045464  0.053519  0.022866  ...  0.009749  0.050794  0.061168
# ETH-GBP  0.023648  0.032724  0.033263  ...  0.012956  0.026583  0.007260
# FAN.L    0.028902  0.021838  0.013618  ...  0.004901  0.011251  0.026713
# FUTR.L   0.041751  0.045629  0.030866  ...  0.016690  0.043291  0.043717
# GSK.L    0.013766  0.026028  0.018534  ...  0.005679  0.011378  0.011548
# GTLY.L   0.017595  0.020253  0.005198  ...  0.010933  0.019517  0.031513
# INDV.L   0.016670  0.026909  0.017987  ...  0.013086  0.018337  0.022521
# JD.L     0.070272  0.060230  0.027501  ...  0.019277  0.036626  0.077415
# KAPE.L   0.023850  0.039867  0.017511  ...  0.005423  0.048479  0.027689
# LUCE.L   0.046460  0.039535  0.024799  ...  0.017876  0.031914  0.055978
# MGGT.L   0.098339  0.090357  0.014332  ...  0.021898  0.017669  0.040058
# MMH.L    0.009850  0.009740  0.004231  ...  0.126707  0.005695  0.016848
# NANO.L   0.018097  0.030401  0.017528  ...  0.005695  0.510803  0.030677
# NFC.L    0.031331  0.037430  0.015258  ...  0.016848  0.030677  0.205254
# PFD.L    0.017472  0.028521  0.008500  ...  0.011966  0.028702  0.013269
# SAFE.L   0.036606  0.023524  0.015815  ...  0.016234  0.022120  0.019262
# SCT.L    0.020070  0.022307  0.021645  ...  0.007740  0.014486  0.027838
# SMT.L    0.030616  0.039144  0.032880  ...  0.012973  0.044377  0.039688
# SPX.L    0.018526  0.021797  0.027549  ...  0.010531  0.020704  0.013117
# WOSG.L   0.060280  0.041851  0.011523  ...  0.014827  0.020126  0.042164
# XTR.L    0.011771  0.022564  0.004608  ... -0.006272  0.035527  0.052483
#
#             PFD.L    SAFE.L     SCT.L     SMT.L     SPX.L    WOSG.L     XTR.L
# AAF.L    0.045525  0.039452  0.028158  0.050168  0.023748  0.051509  0.031638
# AAL.L    0.024269  0.032425  0.030830  0.055661  0.035256  0.043820  0.019655
# AEP.L    0.017173  0.017179  0.011311  0.022843  0.011896  0.014557  0.013901
# AHT.L    0.026894  0.037140  0.033753  0.067100  0.042745  0.052127  0.027715
# BARC.L   0.031390  0.037841  0.026437  0.048661  0.023988  0.067279  0.036363
# BEZ.L    0.018406  0.033026  0.026156  0.038395  0.021909  0.048266  0.006558
# BIFF.L   0.010282  0.011312  0.017783  0.026034  0.020683  0.027405  0.010046
# BLND.L   0.017472  0.036606  0.020070  0.030616  0.018526  0.060280  0.011771
# BP.L     0.028521  0.023524  0.022307  0.039144  0.021797  0.041851  0.022564
# CRDA.L   0.008500  0.015815  0.021645  0.032880  0.027549  0.011523  0.004608
# CWR.L    0.033789  0.051059  0.052070  0.101581  0.048399  0.063725  0.036013
# DPLM.L   0.016271  0.024580  0.031095  0.048837  0.033535  0.038793  0.024580
# ENT.L    0.038943  0.035732  0.039112  0.067092  0.029875  0.059036  0.044450
# ETH-GBP  0.035796  0.024327  0.037356  0.055127  0.022964  0.021785 -0.010977
# FAN.L    0.012453  0.013883  0.020544  0.033155  0.012682  0.057115  0.013745
# FUTR.L   0.018640  0.040637  0.044189  0.077548  0.045193  0.071649  0.011285
# GSK.L    0.009225  0.013874  0.011801  0.023929  0.018069  0.004664 -0.000448
# GTLY.L   0.017616  0.007950  0.012505  0.017899  0.008245  0.015139  0.025118
# INDV.L   0.019878  0.034035  0.021897  0.036507  0.017809  0.041348  0.046366
# JD.L     0.028067  0.044581  0.045076  0.071434  0.031281  0.072081  0.044801
# KAPE.L   0.028698  0.020891  0.028476  0.047137  0.019015  0.022694  0.056820
# LUCE.L   0.052954  0.039656  0.041584  0.063019  0.029919  0.054588  0.021971
# MGGT.L   0.018052  0.037414  0.030711  0.048919  0.024891  0.056107  0.036978
# MMH.L    0.011966  0.016234  0.007740  0.012973  0.010531  0.014827 -0.006272
# NANO.L   0.028702  0.022120  0.014486  0.044377  0.020704  0.020126  0.035527
# NFC.L    0.013269  0.019262  0.027838  0.039688  0.013117  0.042164  0.052483
# PFD.L    0.149634  0.015746  0.013264  0.023748  0.014331  0.015021  0.032040
# SAFE.L   0.015746  0.070297  0.019069  0.028735  0.022687  0.040019  0.006980
# SCT.L    0.013264  0.019069  0.076503  0.041724  0.026272  0.018329  0.026003
# SMT.L    0.023748  0.028735  0.041724  0.101777  0.042845  0.043334  0.018676
# SPX.L    0.014331  0.022687  0.026272  0.042845  0.055484  0.022601  0.010871
# WOSG.L   0.015021  0.040019  0.018329  0.043334  0.022601  0.223962  0.062743
# XTR.L    0.032040  0.006980  0.026003  0.018676  0.010871  0.062743  1.045337
#
# [33 rows x 33 columns]

# %%
prices = pd.DataFrame()
for tick in assets:
    prices[tick] = data.DataReader(tick, data_source='yahoo', start='2020-01-01', end='2022-04-25')['Adj Close']
prices.columns = assets
    
prices
# Out:
#                  AAF.L        AAL.L       AEP.L        AHT.L      BARC.L  \
# Date
# 2020-01-02   73.089569  2024.347534  587.822815  2340.012939  171.548996
# 2020-01-03   72.811302  2010.097778  568.860840  2325.387939  169.789062
# 2020-01-06   72.764923  1971.946045  588.820862  2343.913086  167.640060
# 2020-01-07   73.553337  1985.735596  575.846863  2338.062988  169.640854
# 2020-01-08   72.115654  1979.300415  563.870850  2366.338135  168.621918
# ...                ...          ...         ...          ...         ...
# 2022-04-19  149.399994  4155.000000  926.000000  4592.000000  145.699997
# 2022-04-20  147.699997  4035.500000  926.000000  4776.000000  148.880005
# 2022-04-21  146.600006  3679.000000  902.000000  4817.000000  150.059998
# 2022-04-22  145.899994  3460.500000  808.000000  4639.000000  146.699997
# 2022-04-25  144.000000  3223.500000  854.000000  4394.000000  144.179993
#
#                  BEZ.L      BIFF.L      BLND.L        BP.L       CRDA.L  ...  \
# Date                                                                     ...
# 2020-01-02  542.869873  267.862152  592.339233  400.782745  4947.681152  ...
# 2020-01-03  537.109985  266.868225  593.847839  411.784790  4933.128906  ...
# 2020-01-06  524.630249  260.407745  579.892700  420.161377  4942.830078  ...
# 2020-01-07  524.150269  257.922943  583.287170  415.743805  4937.979492  ...
# 2020-01-08  517.430359  261.401672  568.389160  411.993073  4937.979492  ...
# ...                ...         ...         ...         ...          ...  ...
# 2022-04-19  393.600006  339.200012  512.400024  401.049988  7418.000000  ...
# 2022-04-20  405.000000  336.600006  512.200012  401.149994  7548.000000  ...
# 2022-04-21  414.000000  339.399994  524.200012  403.149994  7678.000000  ...
# 2022-04-22  406.000000  336.399994  516.599976  393.149994  7650.000000  ...
# 2022-04-25  395.399994  331.799988  506.799988  368.850006  7560.000000  ...
#
#                  MMH.L     NANO.L        NFC.L       PFD.L       SAFE.L  \
# Date
# 2020-01-02  140.276184  13.525000   526.575134   37.702827   765.369080
# 2020-01-03  140.731628  13.625000   534.493530   37.603741   763.014099
# 2020-01-06  140.731628  13.800000   536.473145   37.653286   752.652222
# 2020-01-07  140.731628  13.000000   534.493530   36.910126   743.232239
# 2020-01-08  140.731628  13.000000   534.493530   36.662407   733.812317
# ...                ...        ...          ...         ...          ...
# 2022-04-19  394.000000  32.099998  1310.000000  116.599998  1321.000000
# 2022-04-20  394.000000  32.599998  1356.000000  116.599998  1319.000000
# 2022-04-21  394.000000  32.500000  1364.000000  115.400002  1324.000000
# 2022-04-22  394.000000  31.600000  1332.000000  116.599998  1307.000000
# 2022-04-25  394.000000  30.700001  1298.000000  116.000000  1302.000000
#
#                   SCT.L       SMT.L         SPX.L       WOSG.L  XTR.L
# Date
# 2020-01-02  1167.235962  582.167419   8824.490234   390.000000  0.975
# 2020-01-03  1153.595581  582.664124   8804.967773   390.000000  0.975
# 2020-01-06  1124.365845  577.200134   8746.398438   375.399994  0.975
# 2020-01-07  1142.877930  583.160889   8736.636719   383.799988  0.975
# 2020-01-08  1127.288818  586.141174   8736.636719   375.000000  1.000
# ...                 ...         ...           ...          ...    ...
# 2022-04-19  1497.000000  939.799988  12465.000000  1127.000000  6.700
# 2022-04-20  1506.000000  934.799988  12615.000000  1168.000000  6.700
# 2022-04-21  1504.000000  932.000000  12720.000000  1159.000000  6.600
# 2022-04-22  1493.000000  908.000000  12385.000000  1117.000000  6.600
# 2022-04-25  1478.000000  893.200012  12265.000000  1058.000000  6.350
#
# [584 rows x 33 columns]

# %%
# Plotting the timeseries:
timeseries = prices / prices.iloc[0] * 100
timeseries.plot(figsize=(20, 10))
plt.title('Stockprices Time Series', fontsize=20)
plt.legend(bbox_to_anchor=(1,1))

# %%
#Simulation of random portfolio weights:
np.random.seed(42)
weights = np.random.random(size=(n_portfolios, n_assets))
weights /= np.sum(weights, axis=1) [:, np.newaxis]
weights
# Out:
# array([[0.02675088, 0.06790313, 0.0522814 , ..., 0.04339284, 0.01217939,
#         0.0046462 ],
#        [0.05675779, 0.05775948, 0.04835446, ..., 0.02133928, 0.01680416,
#         0.03246148],
#        [0.00870387, 0.04954589, 0.00460445, ..., 0.03228542, 0.02640611,
#         0.00156996],
#        ...,
#        [0.06005211, 0.03367106, 0.02595087, ..., 0.01757933, 0.01195705,
#         0.06138306],
#        [0.05825331, 0.04409827, 0.03689673, ..., 0.03585214, 0.02067275,
#         0.01663401],
#        [0.03572977, 0.05314397, 0.00249123, ..., 0.01226735, 0.016549  ,
#         0.04007599]])

# %%
portf_returns = np.dot(weights, avg_returns)

portf_vol = np.diag(np.sqrt(np.dot(weights, np.dot(cov_mat, weights.T))))
portf_vol = np.array(portf_vol)
portf_sharpe_ratio = portf_returns / portf_vol

# %%
portf_results = pd.DataFrame({'returns': portf_returns,
                             'volatility': portf_vol,
                             'sharpe_ratio': portf_sharpe_ratio})
portf_results
# Out:
#        returns  volatility  sharpe_ratio
# 0     0.240899    0.196511      1.225880
# 1     0.285108    0.225907      1.262062
# 2     0.243163    0.217181      1.119632
# 3     0.254153    0.202893      1.252641
# 4     0.244117    0.210656      1.158840
# ...        ...         ...           ...
# 4995  0.261950    0.199794      1.311098
# 4996  0.323102    0.213650      1.512298
# 4997  0.309304    0.213137      1.451197
# 4998  0.296495    0.205581      1.442229
# 4999  0.307388    0.205531      1.495574
#
# [5000 rows x 3 columns]

# %%
n_points = 25
portf_vol_ef = []
indices_to_skip = []

portf_returns_ef = np.linspace(portf_results.returns.min(),
                               portf_results.returns.max(),
                               n_points)
portf_rerturns_ef = np.round(portf_returns_ef, 2)
portf_returns = np.round(portf_returns, 2)

for point_index in range (n_points):
    if portf_returns_ef[point_index] not in portf_returns:
       indices_to_skip.append(point_index)
       continue
    matched_ind = np.where(portf_returns ==
                           portf_returns_ef[point_index])
    
portf_returns_ef = np.delete(portf_returns_ef, indices_to_skip)

# %%
marks = ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']


fig, ax = plt.subplots()
portf_results.plot(kind='scatter', 
                   x='volatility', 
                   y='returns', 
                   c='sharpe_ratio', 
                   cmap='RdYlGn', 
                   edgecolors='black', 
                   ax=ax)
ax.set(xlabel='Volatility', 
       ylabel='Expected Returns', 
       title='Efficient Frontier')
ax.plot(portf_vol_ef, portf_returns_ef, 'b--')
for asset_index in range(n_assets):
    ax.scatter(x=np.sqrt(cov_mat.iloc[asset_index, asset_index]),
               y=avg_returns[asset_index],
               marker=marks[asset_index],
               s=25,
               color='blue',
               label=assets[asset_index])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [13], in <cell line: 16>()
#      15 ax.plot(portf_vol_ef, portf_returns_ef, 'b--')
#      16 for asset_index in range(n_assets):
#      17     ax.scatter(x=np.sqrt(cov_mat.iloc[asset_index, asset_index]),
#      18                y=avg_returns[asset_index],
# ---> 19                marker=marks[asset_index],
#      20                s=25,
#      21                color='blue',
#      22                label=assets[asset_index])
#
# IndexError: list index out of range

# %%
max_sharpe_ind = np.argmax(portf_results.sharpe_ratio)
max_sharpe_portf = portf_results.loc[max_sharpe_ind]

min_vol_ind = np.argmin(portf_results.volatility)
min_vol_portf = portf_results.loc[min_vol_ind]

# %%
print ('Maximum Sharpe Ratio portfolio ----')
print ('Performance')
for index, value in max_sharpe_portf.items() :
    print(f'{index}: {100 * value:.2f}% ', end="", flush=True)
print('\nWeights')
for x, y in zip(assets,
weights[np.argmax(portf_results.sharpe_ratio)]):
    print(f'{x}: {100*y:.2f}% ', end="", flush=True)
# Out:
# Maximum Sharpe Ratio portfolio ----
# Performance
# returns: 34.35% volatility: 19.01% sharpe_ratio: 180.64%
# Weights
# AAF.L: 1.34% AAL.L: 4.41% AEP.L: 2.85% AHT.L: 5.33% BARC.L: 0.87% BEZ.L: 1.34% BIFF.L: 3.90% BLND.L: 3.50% BP.L: 1.86% CRDA.L: 2.85% CWR.L: 0.24% DPLM.L: 0.26% ENT.L: 0.66% ETH-GBP: 4.03% FAN.L: 6.04% FUTR.L: 1.82% GSK.L: 0.24% GTLY.L: 4.95% INDV.L: 5.98% JD.L: 0.97% KAPE.L: 2.70% LUCE.L: 1.11% MGGT.L: 0.74% MMH.L: 4.53% NANO.L: 6.76% NFC.L: 4.74% PFD.L: 6.88% SAFE.L: 3.04% SCT.L: 6.28% SMT.L: 1.43% SPX.L: 0.82% WOSG.L: 4.91% XTR.L: 2.60%

# %%
print ('Minimum Volatility portfolio ----')
print ('Performance')
for index, value in min_vol_portf.items() :
    print(f'{index}: {100 * value:.2f}% ', end="", flush=True)
print('\nWeights')
for x, y in zip(assets,
weights[np.argmin(portf_results.sharpe_ratio)]):
    print(f'{x}: {100*y:.2f}% ', end="", flush=True)
# Out:
# Minimum Volatility portfolio ----
# Performance
# returns: 25.95% volatility: 18.17% sharpe_ratio: 142.78%
# Weights
# AAF.L: 2.97% AAL.L: 3.45% AEP.L: 1.57% AHT.L: 4.74% BARC.L: 5.36% BEZ.L: 5.86% BIFF.L: 3.34% BLND.L: 2.68% BP.L: 5.37% CRDA.L: 4.86% CWR.L: 5.60% DPLM.L: 4.23% ENT.L: 5.70% ETH-GBP: 0.58% FAN.L: 4.39% FUTR.L: 0.57% GSK.L: 4.84% GTLY.L: 4.06% INDV.L: 0.10% JD.L: 3.87% KAPE.L: 0.94% LUCE.L: 0.92% MGGT.L: 0.97% MMH.L: 3.12% NANO.L: 0.75% NFC.L: 0.81% PFD.L: 1.65% SAFE.L: 0.01% SCT.L: 1.78% SMT.L: 3.99% SPX.L: 3.88% WOSG.L: 6.26% XTR.L: 0.77%

# %%
fig, ax = plt.subplots()
portf_results.plot(kind='scatter',
                   x='volatility',
                   y='returns',
                   cmap='RdYlGn',
                   edgecolors='black',
                   ax=ax)
ax.scatter(x=max_sharpe_portf.volatility,
           y=max_sharpe_portf.returns,
           c='black',
           marker='*',
           s=200,
           label='Max Sharpe Ratio')
ax.scatter(x=min_vol_portf.volatility,
           y=min_vol_portf.returns,
           c='black',
           marker='P',
           s=200,
           label='Minimum Volatility')
ax.set(xlabel='Volatility',
       ylabel='Expected Returns',
       title='Efficient Frontier')
ax.legend()

# %%
# Define functions for calculating portfolio return and volatility:

def get_portf_rtn(w, avg_rtns):
    return np.sum(avg_rtns * w)

def get_portf_vol(w, avg_rtns, cov_mat):
    return np.sqrt(np.dot(w.T, np.dot(cov_mat, w)))

# %%
# Define the function calculating theEfficient Frontier:
def get_efficient_frontier(avg_rtns, cov_mat, rtns_range):
    efficient_portfolios = []
    n_assets = len(avg_returns)
    args = (avg_returns, cov_mat)
    bounds = tuple((0,1) for asset in range (n_assets))
    initial_guess = n_assets * [1. / n_assets, ]
    for ret in rtns_range:
        constraints = ({'type': 'eq',
                        'fun': lambda x: get_portf_rtn(x, avg_rtns) - ret},
                       {'type': 'eq',
                        'fun': lambda x: np.sum(x) - 1})
        efficient_portfolio = sco.minimize(get_portf_vol,
                                           initial_guess,
                                           args=args,
                                           method='SLSQP',
                                           constraints=constraints,
                                           bounds=bounds)
        efficient_portfolios.append(efficient_portfolio)
    return efficient_portfolios

# %%
# Define the considered range of returns
rtns_range = np.linspace (0.16, 0.32, 200)

# %%
# Calculate the Efficient Frontier
efficient_portfolios = get_efficient_frontier(avg_returns,
                                              cov_mat,
                                              rtns_range)

# %%
# Extract the volatilities of the efficient portfolios:
vols_range = [x['fun'] for x in efficient_portfolios]

# %%
# Plot the calculated Efficient Frontier, together with the simulated portfolios:
fig, ax = plt.subplots()
portf_results.plot(kind='scatter',
                   x='volatility',
                   y='returns',
                   c='sharpe_ratio',
                   cmap='RdYlGn',
                   edgecolors='black',
                   ax=ax)
ax.plot(vols_range, rtns_range, 'b--', linewidth=3)
ax.set(xlabel='Volatility',
       ylabel='Expected Returns',
       title='Efficient Frontier')
# Out:
# [Text(0.5, 0, 'Volatility'),
#  Text(0, 0.5, 'Expected Returns'),
#  Text(0.5, 1.0, 'Efficient Frontier')]

# %%
# Identify the minimum volatility portfolio:
min_vol_ind = np.argmin(vols_range)
min_vol_portf_rtn = rtns_range[min_vol_ind]
min_vol_portf_vol = efficient_portfolios[min_vol_ind]['fun']

min_vol_portf = {'Return': min_vol_portf_rtn,
                 'Voltatility': min_vol_portf_rtn,
                 'Sharpe Ratio': (min_vol_portf_rtn /
                                  min_vol_portf_vol)}

# %%
# Print the performance summary:
print ('Minimum volatility portfolio ----')
print ('Performance')

for index, value in min_vol_portf.items():
    print(f'{index}: {100 * value:.2f}% ', end="", flush=True)
    
print('\nWeights')
for x, y in zip (assets,
efficient_portfolios[min_vol_ind]['x']):
    print(f'{x}: {100*y:.2f}% ', end="", flush=True)
# Out:
# Minimum volatility portfolio ----
# Performance
# Return: 16.00% Voltatility: 16.00% Sharpe Ratio: 118.63%
# Weights
# AAF.L: 0.00% AAL.L: 0.00% AEP.L: 5.10% AHT.L: 0.00% BARC.L: 0.00% BEZ.L: 0.00% BIFF.L: 5.37% BLND.L: 0.23% BP.L: 0.00% CRDA.L: 12.31% CWR.L: 0.00% DPLM.L: 0.00% ENT.L: 0.00% ETH-GBP: 0.00% FAN.L: 5.54% FUTR.L: 0.00% GSK.L: 30.92% GTLY.L: 10.80% INDV.L: 0.00% JD.L: 0.00% KAPE.L: 0.00% LUCE.L: 0.00% MGGT.L: 0.00% MMH.L: 9.22% NANO.L: 0.69% NFC.L: 0.00% PFD.L: 4.44% SAFE.L: 6.58% SCT.L: 5.68% SMT.L: 0.00% SPX.L: 1.49% WOSG.L: 0.69% XTR.L: 0.94%

# %%
# Define the objective function for the negative Sharpe Ratio:

def neg_sharpe_ratio(w, avg_rtns, cov_mat, rf_rate) :
    portf_returns = np.sum(avg_rtns * w)
    portf_volatility = np.sqrt(np.dot(w.T, np.dot(cov_mat, w)))
    portf_sharpe_ratio = (portf_returns - rf_rate) / portf_volatility
    return -portf_sharpe_ratio

# %%
# Finding the optimized portfolio:
n_assets = len(avg_returns)
rf_rate = 0.01

args = (avg_returns, cov_mat, rf_rate)
constraints = ({'type': 'eq',
                'fun': lambda x: np.sum(x) - 1})
bounds = tuple((0,1) for asset in range (n_assets))
initial_guess = n_assets * [1. / n_assets]

max_sharpe_portf = sco.minimize(neg_sharpe_ratio,
                                x0=initial_guess,
                                args=args,
                                method='SLSQP',
                                bounds=bounds,
                                constraints=constraints)

# %%
# Extracting information about the maximu Sharpe Ratio portfolio:
max_sharpe_portf_w = max_sharpe_portf['x']
max_sharpe_portf = {'Return': get_portf_rtn(max_sharpe_portf_w,
                                            avg_returns),
                    'Volatility': get_portf_vol(max_sharpe_portf_w, 
                                            avg_returns,
                                            cov_mat),
                    'Sharpe Ratio': -max_sharpe_portf['fun']}

# %%
# Printing performance summary:
print ('Maximum Sharpe Ratio portfolio ----')
print ('Performance')

for index, value in max_sharpe_portf.items():
    print(f'{index}: {100*value:.2f}% ', end="", flush=True)
    
print('\nWeights')
for x, y in zip (assets, max_sharpe_portf_w):
    print(f'{x}: {100*y:.2f}% ', end="", flush=True)
# Out:
# Maximum Sharpe Ratio portfolio ----
# Performance
# Return: 65.90% Volatility: 25.08% Sharpe Ratio: 258.76%
# Weights
# AAF.L: 0.00% AAL.L: 0.00% AEP.L: 0.00% AHT.L: 0.00% BARC.L: 0.00% BEZ.L: 0.00% BIFF.L: 0.00% BLND.L: 0.00% BP.L: 0.00% CRDA.L: 0.00% CWR.L: 0.00% DPLM.L: 0.00% ENT.L: 0.00% ETH-GBP: 16.79% FAN.L: 2.83% FUTR.L: 0.00% GSK.L: 0.00% GTLY.L: 0.00% INDV.L: 20.04% JD.L: 0.00% KAPE.L: 0.00% LUCE.L: 0.00% MGGT.L: 0.00% MMH.L: 20.47% NANO.L: 5.82% NFC.L: 7.80% PFD.L: 13.48% SAFE.L: 0.00% SCT.L: 0.00% SMT.L: 0.00% SPX.L: 0.00% WOSG.L: 5.61% XTR.L: 7.16%

# %%
# Convert the annualised average returns and the covariance matrix to numpy arrays:
avg_returns = avg_returns.values
cov_mat = cov_mat.values

# %%
# Set up the optimization problem
weights = cp.Variable(n_assets)
gamma = cp.Parameter(nonneg=True)
portf_rtn_cvx = avg_returns @ weights
portf_vol_cvx = cp.quad_form(weights, cov_mat)
objective_function = cp.Maximize(portf_rtn_cvx - gamma * portf_vol_cvx)
problem = cp.Problem(objective_function,
                     [cp.sum(weights) == 1, weights>= 0])

# %%
# Calculate the Efficient Frontier
n_points = 25
portf_rtn_cvx_ef = np.zeros(n_points)
portf_vol_cvx_ef = np.zeros(n_points)
weights_ef = []
gamma_range = np.logspace(-3, 3, num=n_points)

for i in range (n_points) :
    gamma.value = gamma_range[i]
    problem.solve()
    portf_vol_cvx_ef[i] = cp.sqrt(portf_vol_cvx).value
    portf_rtn_cvx_ef[i] = portf_rtn_cvx.value
    weights_ef.append(weights.value)

# %%
# Plot the allocation for different values of the risk-aversion parameter
weights_df = pd.DataFrame(weights_ef,
                          columns=assets,
                          index=np.round(gamma_range, 3))
ax = weights_df.plot(kind='bar', stacked=True)
ax.set(title='Allocation of Weights per Risk-Aversion level',
       xlabel=r'$\gamma$',
       ylabel='weight')
ax.legend(bbox_to_anchor=(1,1))

# %%
# Plotting the Efficient Frontier with individual assets
MARKS = ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
fig, ax = plt.subplots()
ax.plot(portf_vol_cvx_ef, portf_rtn_cvx_ef, 'g-')
for asset_index in range(n_assets):
     plt.scatter(x=np.sqrt(cov_mat[asset_index, asset_index]),
                 y=avg_returns[asset_index],
                 marker=MARKS[asset_index],
                 label=assets[asset_index],
                 s=200)
ax.set(title='Efficient Frontier',
       xlabel='Volatility',
       ylabel='Expcted Returns', )
ax.legend(bbox_to_anchor=(1,1))

# %%
# Efficient frontier comparison
x_lim = [0.1, 0.5]
y_lim = [0.1, 2]

fig, ax = plt.subplots(1, 2)
ax[0].plot(vols_range, rtns_range, 'g-', linewidth=3)
ax[0].set(title='Minimized volatility',
          xlabel='Volatility',
          ylabel='Expected Returns',
          xlim=x_lim,
          ylim=y_lim)

ax[1].plot(portf_vol_cvx_ef, portf_rtn_cvx_ef, 'g-', linewidth=3)
ax[1].set(title='Maximized Risk-Adjusted Retrun',
          xlabel='Volatility',
          ylabel='Expected Returns',
          xlim=x_lim,
          ylim=y_lim)
# Out:
# [Text(0.5, 1.0, 'Maximized Risk-Adjusted Retrun'),
#  Text(0.5, 0, 'Volatility'),
#  Text(0, 0.5, 'Expected Returns'),
#  (0.1, 0.5),
#  (0.1, 2.0)]

# %%
# Analysing maximum allowable leverage
max_leverage= cp.Parameter()
problem_with_leverage = cp.Problem(objective_function,
                                   [cp.sum(weights) == 1,
                                    cp.norm(weights, 1) <= max_leverage])

# %%
# Redefining objects in order to store the results to be either larger 2D matrices or 3 = [1, 2, 5]
leverage_range = [1, 2, 5]
len_leverage = len(leverage_range)
n_points = 25

portf_vol_l_ef = np.zeros((n_points, len_leverage))
portf_rtn_l_ef = np.zeros((n_points, len_leverage))
weights_ef =np.zeros((len_leverage, n_points, n_assets))

for lev_ind, leverage in enumerate(leverage_range) :
    for gamma_ind in range(n_points):
        max_leverage.value = leverage
        gamma.value = gamma_range[gamma_ind]
        problem_with_leverage.solve(verbose=True)
        portf_vol_l_ef[gamma_ind, lev_ind] = cp.sqrt(portf_vol_cvx).value
        portf_rtn_l_ef[gamma_ind, lev_ind] = portf_rtn_cvx.value
        weights_ef[lev_ind, gamma_ind, :] = weights.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Compiling problem (target solver=OSQP).
# (CVXPY) May 12 06:20:19 AM: Reduction chain: FlipObjective -> CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) May 12 06:20:19 AM: Applying reduction FlipObjective
# (CVXPY) May 12 06:20:19 AM: Applying reduction CvxAttr2Constr
# (CVXPY) May 12 06:20:19 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) May 12 06:20:19 AM: Applying reduction QpMatrixStuffing
# (CVXPY) May 12 06:20:19 AM: Applying reduction OSQP
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 1.944e-02 seconds).
# (CVXPY) May 12 06:20:19 AM: (Subsequent compilations of this problem, using the same arguments, should take less time.)
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 66, constraints m = 68
#           nnz(P) + nnz(A) = 759
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.5239e+01   6.17e+00   1.28e+02   1.00e-01   1.99e-04s
#  200  -1.0493e+00   1.37e-02   8.94e-03   2.07e-01   2.07e-03s
#  400  -1.2820e+00   1.72e-04   2.80e-03   2.07e-01   2.70e-03s
#  600  -1.2880e+00   5.28e-04   4.17e-05   4.11e-02   3.41e-03s
#  775  -1.2790e+00   5.71e-06   1.36e-05   4.11e-02   3.96e-03s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 775
# optimal objective:    -1.2790
# run time:             4.10e-03s
# optimal rho estimate: 2.13e-02
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 1.279e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 1.944e-02 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 5.006e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 5.038e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -1.2651e+00   1.39e-02   7.20e-04   4.11e-02   9.68e-04s
#  200  -1.2793e+00   4.33e-05   2.99e-06   4.11e-02   1.60e-03s
#  225  -1.2790e+00   1.96e-05   6.34e-06   4.11e-02   2.41e-03s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 225
# optimal objective:    -1.2790
# run time:             2.77e-03s
# optimal rho estimate: 5.77e-02
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 1.279e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 5.038e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 5.038e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -1.2540e+00   2.44e-02   1.29e-03   4.11e-02   1.56e-04s
#  200  -1.2781e+00   2.24e-05   7.03e-07   4.11e-02   8.53e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 200
# optimal objective:    -1.2781
# run time:             1.02e-03s
# optimal rho estimate: 1.85e-01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 1.278e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 5.038e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 0.000e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -1.2350e+00   4.22e-02   2.22e-03   4.11e-02   2.24e-04s
#  125  -1.2758e+00   2.16e-05   1.71e-05   4.11e-02   6.84e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 125
# optimal objective:    -1.2758
# run time:             8.61e-04s
# optimal rho estimate: 3.69e-02
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 1.276e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 0.000e+00 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 5.005e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 5.058e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -1.2029e+00   7.16e-02   3.75e-03   4.11e-02   1.57e-04s
#  200  -1.2745e+00   7.39e-05   1.97e-05   1.33e-01   9.23e-04s
#  250  -1.2735e+00   1.52e-05   1.85e-05   1.33e-01   1.11e-03s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 250
# optimal objective:    -1.2735
# run time:             1.29e-03s
# optimal rho estimate: 9.65e-02
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 1.274e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 5.058e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 5.006e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 5.064e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -1.2285e+00   4.13e-02   7.05e-03   1.33e-01   2.29e-04s
#  175  -1.2683e+00   7.61e-06   6.77e-06   1.33e-01   8.46e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 175
# optimal objective:    -1.2683
# run time:             1.06e-03s
# optimal rho estimate: 1.13e-01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 1.268e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 5.064e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 5.116e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -1.1925e+00   7.01e-02   1.19e-02   1.33e-01   1.53e-04s
#  200  -1.2599e+00   4.29e-05   1.26e-05   2.41e-01   7.79e-04s
#  225  -1.2594e+00   1.47e-05   2.13e-05   2.41e-01   9.44e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 225
# optimal objective:    -1.2594
# run time:             1.11e-03s
# optimal rho estimate: 1.60e-01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 1.259e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 5.116e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 5.058e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -1.1796e+00   6.90e-02   2.13e-02   2.41e-01   4.15e-04s
#  175  -1.2434e+00   1.39e-05   1.54e-05   2.13e-01   1.11e-03s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 175
# optimal objective:    -1.2434
# run time:             1.47e-03s
# optimal rho estimate: 1.62e-01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 1.243e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 5.058e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 9.870e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -1.1037e+00   1.26e-01   3.43e-02   2.13e-01   3.19e-04s
#   75  -1.2146e+00   5.29e-06   1.23e-05   2.13e-01   7.22e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 75
# optimal objective:    -1.2146
# run time:             9.10e-04s
# optimal rho estimate: 1.12e-01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 1.215e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 9.870e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 0.000e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -1.0052e+00   1.96e-01   5.34e-02   2.13e-01   2.43e-04s
#   50  -1.1641e+00   7.69e-06   6.31e-06   2.13e-01   5.03e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 50
# optimal objective:    -1.1641
# run time:             6.89e-04s
# optimal rho estimate: 1.88e-01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 1.164e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 0.000e+00 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 2.550e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -8.7874e-01   2.85e-01   7.77e-02   2.13e-01   2.79e-04s
#   25  -1.0822e+00   9.64e-06   3.88e-06   2.13e-01   5.07e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 25
# optimal objective:    -1.0822
# run time:             7.98e-04s
# optimal rho estimate: 2.87e-01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 1.082e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 2.550e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 2.550e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 0.000e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -7.3162e-01   3.34e-01   9.12e-02   2.13e-01   2.37e-04s
#   50  -9.6840e-01   5.16e-07   3.85e-07   2.13e-01   4.96e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 50
# optimal objective:    -0.9684
# run time:             2.20e-03s
# optimal rho estimate: 2.28e-01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 9.684e-01
# (CVXPY) May 12 06:20:19 AM: Compilation took 0.000e+00 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 9.537e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 0.000e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -5.9203e-01   3.57e-01   1.60e-01   2.13e-01   1.56e-04s
#   50  -8.3088e-01   3.07e-06   1.73e-06   2.13e-01   4.43e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 50
# optimal objective:    -0.8309
# run time:             7.06e-04s
# optimal rho estimate: 3.07e-01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 8.309e-01
# (CVXPY) May 12 06:20:19 AM: Compilation took 0.000e+00 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 5.040e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -4.4861e-01   3.24e-01   2.79e-01   2.13e-01   1.56e-04s
#  125  -6.6309e-01   8.56e-06   6.34e-07   2.13e-01   6.87e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 125
# optimal objective:    -0.6631
# run time:             8.91e-04s
# optimal rho estimate: 6.59e-01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 6.631e-01
# (CVXPY) May 12 06:20:19 AM: Compilation took 5.040e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 0.000e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -3.3613e-01   2.65e-01   4.20e-01   2.13e-01   1.56e-04s
#   50  -4.8456e-01   4.97e-07   1.70e-07   1.14e+00   4.38e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 50
# optimal objective:    -0.4846
# run time:             6.15e-04s
# optimal rho estimate: 1.23e+00
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 4.846e-01
# (CVXPY) May 12 06:20:19 AM: Compilation took 0.000e+00 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 5.038e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 5.086e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -2.4753e-01   1.58e-01   4.69e-01   1.14e+00   3.14e-04s
#   75  -3.0636e-01   8.70e-07   4.96e-08   1.14e+00   6.17e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 75
# optimal objective:    -0.3064
# run time:             7.94e-04s
# optimal rho estimate: 1.96e+00
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 3.064e-01
# (CVXPY) May 12 06:20:19 AM: Compilation took 5.086e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 9.790e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1  -1.1039e-01   1.54e-01   5.92e-01   1.14e+00   3.19e-04s
#  150  -1.1878e-01   8.01e-06   7.58e-08   1.14e+00   8.42e-04s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 150
# optimal objective:    -0.1188
# run time:             9.83e-04s
# optimal rho estimate: 2.94e+00
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: 1.188e-01
# (CVXPY) May 12 06:20:19 AM: Compilation took 9.790e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 9.719e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1   6.5879e-02   1.45e-01   6.91e-01   1.14e+00   2.42e-04s
#  200   8.2509e-02   5.96e-04   2.95e-06   1.14e+00   9.60e-04s
#  400   8.5425e-02   2.31e-04   1.53e-06   1.14e+00   1.60e-03s
#  600   8.6569e-02   9.24e-05   6.20e-07   1.14e+00   2.29e-03s
#  800   8.7030e-02   3.70e-05   2.49e-07   1.14e+00   2.92e-03s
#  950   8.7184e-02   1.86e-05   1.25e-07   1.14e+00   3.37e-03s
# plsh   8.7340e-02   2.64e-16   6.74e-16   --------   3.61e-03s
#
# status:               solved
# solution polish:      successful
# number of iterations: 950
# optimal objective:    0.0873
# run time:             3.61e-03s
# optimal rho estimate: 2.54e+00
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: -8.734e-02
# (CVXPY) May 12 06:20:19 AM: Compilation took 9.719e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 0.000e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1   3.1795e-01   8.65e-02   8.27e-01   1.14e+00   2.76e-04s
#  200   3.6851e-01   6.39e-04   2.36e-05   6.43e+00   1.10e-03s
#  400   3.7432e-01   1.23e-04   4.73e-06   6.43e+00   1.75e-03s
#  600   3.7547e-01   2.37e-05   9.15e-07   6.43e+00   2.75e-03s
#  625   3.7552e-01   1.93e-05   7.45e-07   6.43e+00   3.00e-03s
# plsh   3.7575e-01   2.00e-14   3.30e-15   --------   3.17e-03s
#
# status:               solved
# solution polish:      successful
# number of iterations: 625
# optimal objective:    0.3758
# run time:             3.17e-03s
# optimal rho estimate: 4.56e+00
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: -3.758e-01
# (CVXPY) May 12 06:20:19 AM: Compilation took 0.000e+00 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 2.091e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1   7.3086e-01   4.81e-02   1.06e+00   6.43e+00   2.29e-04s
#  200   8.1413e-01   1.70e-03   7.69e-06   6.43e+00   8.96e-04s
#  400   8.2750e-01   9.03e-04   5.32e-06   6.43e+00   1.57e-03s
#  600   8.3472e-01   4.87e-04   2.99e-06   6.43e+00   2.25e-03s
#  800   8.3870e-01   2.71e-04   5.19e-07   6.43e+00   2.95e-03s
# 1000   8.3997e-01   2.07e-04   5.27e-07   6.43e+00   3.78e-03s
# 1200   8.4065e-01   1.74e-04   4.50e-07   6.43e+00   4.46e-03s
# 1400   8.4116e-01   1.45e-04   3.77e-07   6.43e+00   5.21e-03s
# 1600   8.4159e-01   1.21e-04   3.14e-07   6.43e+00   5.86e-03s
# 1800   8.4195e-01   1.01e-04   2.62e-07   6.43e+00   6.62e-03s
# 2000   8.4225e-01   8.42e-05   2.18e-07   6.43e+00   7.27e-03s
# 2200   8.4250e-01   7.02e-05   1.82e-07   6.43e+00   7.99e-03s
# 2400   8.4271e-01   5.85e-05   1.52e-07   6.43e+00   8.80e-03s
# 2600   8.4289e-01   4.88e-05   1.27e-07   6.43e+00   9.54e-03s
# 2800   8.4304e-01   4.07e-05   1.05e-07   6.43e+00   1.02e-02s
# 3000   8.4316e-01   3.39e-05   8.79e-08   6.43e+00   1.09e-02s
# 3200   8.4326e-01   2.82e-05   7.33e-08   6.43e+00   1.15e-02s
# 3400   8.4335e-01   2.35e-05   6.11e-08   6.43e+00   1.22e-02s
# 3600   8.4342e-01   1.96e-05   5.09e-08   6.43e+00   1.29e-02s
# plsh   8.4378e-01   3.70e-11   3.82e-12   --------   1.32e-02s
#
# status:               solved
# solution polish:      successful
# number of iterations: 3600
# optimal objective:    0.8438
# run time:             1.32e-02s
# optimal rho estimate: 1.38e+01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: -8.438e-01
# (CVXPY) May 12 06:20:19 AM: Compilation took 2.091e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 1.569e-02 seconds
# ...
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1   1.4431e+00   5.07e-02   1.77e+00   6.43e+00   1.59e-04s
#  200   1.5669e+00   5.36e-03   1.82e-06   6.43e+00   8.82e-04s
#  400   1.5871e+00   2.31e-03   1.14e-06   6.43e+00   1.53e-03s
#  600   1.5998e+00   1.67e-03   1.26e-06   6.43e+00   2.34e-03s
#  800   1.6096e+00   1.32e-03   1.14e-06   6.43e+00   3.39e-03s
# 1000   1.6170e+00   1.07e-03   1.03e-06   6.43e+00   4.88e-03s
# 1200   1.6227e+00   8.78e-04   8.99e-07   6.43e+00   5.54e-03s
# 1400   1.6273e+00   7.19e-04   2.89e-07   6.43e+00   6.32e-03s
# 1600   1.6302e+00   6.41e-04   2.51e-07   6.43e+00   6.98e-03s
# 1800   1.6321e+00   5.85e-04   2.52e-07   6.43e+00   7.75e-03s
# 2000   1.6335e+00   5.40e-04   2.46e-07   6.43e+00   8.41e-03s
# 2200   1.6346e+00   5.05e-04   2.36e-07   6.43e+00   9.18e-03s
# 2400   1.6356e+00   4.79e-04   2.25e-07   6.43e+00   9.83e-03s
# 2600   1.6364e+00   4.53e-04   2.13e-07   6.43e+00   1.06e-02s
# 2800   1.6372e+00   4.28e-04   2.02e-07   6.43e+00   1.13e-02s
# 3000   1.6379e+00   4.04e-04   1.91e-07   6.43e+00   1.20e-02s
# 3200   1.6386e+00   3.82e-04   1.80e-07   6.43e+00   1.27e-02s
# 3400   1.6393e+00   3.60e-04   1.70e-07   6.43e+00   1.35e-02s
# 3600   1.6399e+00   3.40e-04   1.61e-07   6.43e+00   1.41e-02s
# 3800   1.6405e+00   3.21e-04   1.52e-07   6.43e+00   1.49e-02s
# 4000   1.6410e+00   3.03e-04   1.43e-07   6.43e+00   1.56e-02s
# 4200   1.6415e+00   2.86e-04   1.35e-07   6.43e+00   1.67e-02s
# 4400   1.6420e+00   2.69e-04   1.27e-07   6.43e+00   1.77e-02s
# 4600   1.6425e+00   2.54e-04   1.20e-07   6.43e+00   1.85e-02s
# 4800   1.6430e+00   2.40e-04   1.13e-07   6.43e+00   1.92e-02s
# 5000   1.6434e+00   2.26e-04   1.07e-07   6.43e+00   2.04e-02s
# 5200   1.6438e+00   2.13e-04   1.01e-07   6.43e+00   2.09e-02s
# 5400   1.6442e+00   2.01e-04   9.52e-08   6.43e+00   2.18e-02s
# 5600   1.6445e+00   1.90e-04   8.98e-08   6.43e+00   2.24e-02s
# 5800   1.6449e+00   1.79e-04   8.47e-08   6.43e+00   2.32e-02s
# 6000   1.6452e+00   1.69e-04   7.99e-08   6.43e+00   2.40e-02s
# 6200   1.6455e+00   1.59e-04   7.54e-08   6.43e+00   2.48e-02s
# 6400   1.6458e+00   1.50e-04   7.11e-08   6.43e+00   2.55e-02s
# 6600   1.6461e+00   1.42e-04   6.71e-08   6.43e+00   2.63e-02s
# 6800   1.6463e+00   1.34e-04   6.33e-08   6.43e+00   2.70e-02s
# 7000   1.6466e+00   1.26e-04   5.97e-08   6.43e+00   2.78e-02s
# 7200   1.6468e+00   1.19e-04   5.63e-08   6.43e+00   2.85e-02s
# 7400   1.6471e+00   1.12e-04   5.31e-08   6.43e+00   2.94e-02s
# 7600   1.6473e+00   1.06e-04   5.01e-08   6.43e+00   3.00e-02s
# 7800   1.6475e+00   1.00e-04   4.73e-08   6.43e+00   3.08e-02s
# 8000   1.6477e+00   9.43e-05   4.46e-08   6.43e+00   3.17e-02s
# 8200   1.6478e+00   8.90e-05   4.21e-08   6.43e+00   3.24e-02s
# 8400   1.6480e+00   8.39e-05   3.97e-08   6.43e+00   3.31e-02s
# 8600   1.6482e+00   7.92e-05   3.74e-08   6.43e+00   3.38e-02s
# 8800   1.6483e+00   7.47e-05   3.53e-08   6.43e+00   3.44e-02s
# 9000   1.6485e+00   7.05e-05   3.33e-08   6.43e+00   3.50e-02s
# 9200   1.6486e+00   6.65e-05   3.14e-08   6.43e+00   3.56e-02s
# 9400   1.6487e+00   6.27e-05   2.96e-08   6.43e+00   3.62e-02s
# 9600   1.6488e+00   5.92e-05   2.80e-08   6.43e+00   3.67e-02s
# 9800   1.6489e+00   5.58e-05   2.64e-08   6.43e+00   3.73e-02s
# 10000   1.6491e+00   5.26e-05   2.49e-08   6.43e+00   3.79e-02s
#
# status:               solved inaccurate
# number of iterations: 10000
# optimal objective:    1.6491
# run time:             3.80e-02s
# optimal rho estimate: 2.56e+01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal_inaccurate
# (CVXPY) May 12 06:20:19 AM: Optimal value: -1.649e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 5.006e-03 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 3.502e-02 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 0.000e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1   1.0914e+00   3.50e-01   1.89e+04   6.43e+00   9.07e-04s
#  200   2.8332e+00   7.70e-03   2.16e-05   3.41e+01   1.78e-03s
#  400   2.9170e+00   3.10e-03   1.09e-05   3.41e+01   2.39e-03s
#  600   2.9659e+00   2.01e-03   1.04e-05   3.41e+01   2.99e-03s
#  800   2.9972e+00   1.34e-03   6.74e-06   3.41e+01   3.59e-03s
# 1000   3.0168e+00   9.69e-04   2.42e-06   3.41e+01   4.19e-03s
# 1200   3.0275e+00   7.78e-04   1.68e-06   3.41e+01   4.78e-03s
# 1400   3.0333e+00   6.75e-04   1.60e-06   3.41e+01   5.38e-03s
# 1600   3.0372e+00   6.07e-04   1.48e-06   3.41e+01   5.98e-03s
# 1800   3.0404e+00   5.52e-04   1.35e-06   3.41e+01   6.58e-03s
# 2000   3.0432e+00   5.01e-04   1.23e-06   3.41e+01   7.18e-03s
# 2200   3.0457e+00   4.54e-04   1.12e-06   3.41e+01   7.78e-03s
# 2400   3.0480e+00   4.11e-04   1.01e-06   3.41e+01   8.38e-03s
# 2600   3.0501e+00   3.72e-04   9.15e-07   3.41e+01   8.97e-03s
# 2800   3.0520e+00   3.37e-04   8.29e-07   3.41e+01   9.57e-03s
# 3000   3.0538e+00   3.05e-04   7.50e-07   3.41e+01   1.02e-02s
# 3200   3.0554e+00   2.76e-04   6.79e-07   3.41e+01   1.08e-02s
# 3400   3.0569e+00   2.50e-04   6.14e-07   3.41e+01   1.14e-02s
# 3600   3.0582e+00   2.26e-04   5.56e-07   3.41e+01   1.20e-02s
# 3800   3.0595e+00   2.04e-04   5.03e-07   3.41e+01   1.28e-02s
# 4000   3.0606e+00   1.85e-04   4.55e-07   3.41e+01   1.34e-02s
# 4200   3.0616e+00   1.67e-04   4.12e-07   3.41e+01   1.40e-02s
# 4400   3.0626e+00   1.52e-04   3.73e-07   3.41e+01   1.46e-02s
# 4600   3.0635e+00   1.37e-04   3.38e-07   3.41e+01   1.52e-02s
# 4800   3.0642e+00   1.24e-04   3.06e-07   3.41e+01   1.58e-02s
# 5000   3.0649e+00   1.12e-04   2.77e-07   3.41e+01   1.64e-02s
# 5200   3.0656e+00   1.02e-04   2.50e-07   3.41e+01   1.70e-02s
# 5400   3.0662e+00   9.20e-05   2.27e-07   3.41e+01   1.77e-02s
# 5600   3.0667e+00   8.33e-05   2.05e-07   3.41e+01   1.85e-02s
# 5800   3.0672e+00   7.54e-05   1.86e-07   3.41e+01   1.91e-02s
# 6000   3.0676e+00   6.82e-05   1.68e-07   3.41e+01   1.97e-02s
# 6200   3.0680e+00   6.17e-05   1.52e-07   3.41e+01   2.03e-02s
# 6400   3.0684e+00   5.59e-05   1.38e-07   3.41e+01   2.09e-02s
# 6600   3.0687e+00   5.06e-05   1.25e-07   3.41e+01   2.15e-02s
# 6800   3.0690e+00   4.58e-05   1.13e-07   3.41e+01   2.21e-02s
# 7000   3.0693e+00   4.14e-05   1.02e-07   3.41e+01   2.27e-02s
# 7200   3.0695e+00   3.75e-05   9.23e-08   3.41e+01   2.34e-02s
# 7400   3.0698e+00   3.39e-05   8.35e-08   3.41e+01   2.40e-02s
# 7600   3.0700e+00   3.07e-05   7.56e-08   3.41e+01   2.46e-02s
# 7800   3.0701e+00   2.78e-05   6.84e-08   3.41e+01   2.52e-02s
# 8000   3.0703e+00   2.51e-05   6.20e-08   3.41e+01   2.58e-02s
# 8200   3.0705e+00   2.28e-05   5.60e-08   3.41e+01   2.64e-02s
# 8400   3.0706e+00   2.06e-05   5.07e-08   3.41e+01   2.70e-02s
# 8475   3.0706e+00   1.98e-05   4.88e-08   3.41e+01   2.73e-02s
# plsh   3.0719e+00   2.41e-07   7.98e-09   --------   2.76e-02s
#
# status:               solved
# solution polish:      successful
# number of iterations: 8475
# optimal objective:    3.0719
# run time:             2.76e-02s
# optimal rho estimate: 4.77e+01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Problem status: optimal
# (CVXPY) May 12 06:20:19 AM: Optimal value: -3.072e+00
# (CVXPY) May 12 06:20:19 AM: Compilation took 0.000e+00 seconds
# (CVXPY) May 12 06:20:19 AM: Solver (including time spent in interface) took 3.495e-02 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 12 06:20:19 AM: Your problem has 33 variables, 2 constraints, and 2 parameters.
# (CVXPY) May 12 06:20:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 12 06:20:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Using cached ASA map, for faster compilation (bypassing reduction chain).
# (CVXPY) May 12 06:20:19 AM: Finished problem compilation (took 5.052e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 12 06:20:19 AM: Invoking solver OSQP  to obtain a solution.
# iter   objective    pri res    dua res    rho        time
#    1   4.9273e+00   5.13e-02   5.41e+00   3.41e+01   2.53e-04s
#  200   5.2777e+00   8.17e-03   3.94e-06   3.41e+01   9.43e-04s
#  400   5.3557e+00   5.23e-03   2.81e-06   3.41e+01   1.59e-03s
#  600   5.3997e+00   3.18e-03   1.99e-06   3.41e+01   2.32e-03s
#  800   5.4286e+00   2.22e-03   1.28e-06   3.41e+01   3.03e-03s
# 1000   5.4494e+00   1.57e-03   8.41e-07   3.41e+01   3.87e-03s
# 1200   5.4650e+00   1.26e-03   5.56e-07   3.41e+01   4.52e-03s
# 1400   5.4770e+00   1.14e-03   4.96e-07   3.41e+01   5.12e-03s
# 1600   5.4865e+00   1.04e-03   4.91e-07   3.41e+01   5.72e-03s
# 1800   5.4945e+00   9.50e-04   4.76e-07   3.41e+01   6.32e-03s
# 2000   5.5014e+00   8.88e-04   3.43e-07   3.41e+01   6.92e-03s
# 2200   5.5069e+00   8.30e-04   3.37e-07   3.41e+01   7.52e-03s
# 2400   5.5113e+00   7.87e-04   3.32e-07   3.41e+01   8.12e-03s
# 2600   5.5150e+00   7.51e-04   3.27e-07   3.41e+01   8.72e-03s
# 2800   5.5181e+00   7.18e-04   3.21e-07   3.41e+01   9.32e-03s
# 3000   5.5208e+00   6.89e-04   3.15e-07   3.41e+01   1.02e-02s
# 3200   5.5233e+00   6.65e-04   3.07e-07   3.41e+01   1.08e-02s
# 3400   5.5256e+00   6.46e-04   2.99e-07   3.41e+01   1.14e-02s
# 3600   5.5277e+00   6.26e-04   2.91e-07   3.41e+01   1.21e-02s
# 3800   5.5297e+00   6.07e-04   2.83e-07   3.41e+01   1.26e-02s
# 4000   5.5315e+00   5.88e-04   2.74e-07   3.41e+01   1.32e-02s
# 4200   5.5333e+00   5.70e-04   2.66e-07   3.41e+01   1.39e-02s
# 4400   5.5351e+00   5.52e-04   2.58e-07   3.41e+01   1.44e-02s
# 4600   5.5367e+00   5.35e-04   2.50e-07   3.41e+01   1.50e-02s
# 4800   5.5383e+00   5.18e-04   2.42e-07   3.41e+01   1.56e-02s
# 5000   5.5399e+00   5.01e-04   2.34e-07   3.41e+01   1.63e-02s
# 5200   5.5414e+00   4.85e-04   2.27e-07   3.41e+01   1.69e-02s
# 5400   5.5429e+00   4.70e-04   2.20e-07   3.41e+01   1.77e-02s
# 5600   5.5443e+00   4.55e-04   2.13e-07   3.41e+01   1.83e-02s
# 5800   5.5457e+00   4.40e-04   2.06e-07   3.41e+01   1.90e-02s
# 6000   5.5471e+00   4.26e-04   2.00e-07   3.41e+01   1.96e-02s
# 6200   5.5484e+00   4.12e-04   1.93e-07   3.41e+01   2.02e-02s
# 6400   5.5497e+00   3.99e-04   1.87e-07   3.41e+01   2.07e-02s
# 6600   5.5509e+00   3.86e-04   1.81e-07   3.41e+01   2.13e-02s
# 6800   5.5521e+00   3.74e-04   1.75e-07   3.41e+01   2.19e-02s
# 7000   5.5533e+00   3.62e-04   1.69e-07   3.41e+01   2.25e-02s
# 7200   5.5544e+00   3.50e-04   1.64e-07   3.41e+01   2.31e-02s
# 7400   5.5555e+00   3.39e-04   1.59e-07   3.41e+01   2.37e-02s
# 7600   5.5566e+00   3.28e-04   1.54e-07   3.41e+01   2.43e-02s
# 7800   5.5577e+00   3.18e-04   1.49e-07   3.41e+01   2.49e-02s
# 8000   5.5587e+00   3.07e-04   1.44e-07   3.41e+01   2.55e-02s
# 8200   5.5597e+00   2.97e-04   1.39e-07   3.41e+01   2.61e-02s
# 8400   5.5607e+00   2.88e-04   1.35e-07   3.41e+01   2.68e-02s
# 8600   5.5616e+00   2.79e-04   1.30e-07   3.41e+01   2.74e-02s
# 8800   5.5625e+00   2.70e-04   1.26e-07   3.41e+01   2.80e-02s
# 9000   5.5634e+00   2.61e-04   1.22e-07   3.41e+01   2.86e-02s
# 9200   5.5643e+00   2.53e-04   1.18e-07   3.41e+01   2.92e-02s
# 9400   5.5651e+00   2.45e-04   1.15e-07   3.41e+01   2.98e-02s
# 9600   5.5659e+00   2.37e-04   1.11e-07   3.41e+01   3.04e-02s
# 9800   5.5667e+00   2.29e-04   1.07e-07   3.41e+01   3.10e-02s
# 10000   5.5675e+00   2.22e-04   1.04e-07   3.41e+01   3.16e-02s
#
# status:               maximum iterations reached
# number of iterations: 10000
# run time:             3.16e-02s
# optimal rho estimate: 8.99e+01
# C:\Users\Szenes Ibolya\anaconda3\envs\diss\lib\site-packages\cvxpy\problems\problem.py:1333: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# Input In [37], in <cell line: 10>()
#      12 max_leverage.value = leverage
#      13 gamma.value = gamma_range[gamma_ind]
# ---> 14 problem_with_leverage.solve(verbose=True)
#      15 portf_vol_l_ef[gamma_ind, lev_ind] = cp.sqrt(portf_vol_cvx).value
#      16 portf_rtn_l_ef[gamma_ind, lev_ind] = portf_rtn_cvx.value
#
# File ~\anaconda3\envs\diss\lib\site-packages\cvxpy\problems\problem.py:481, in Problem.solve(self, *args, **kwargs)
#     479 else:
#     480     solve_func = Problem._solve
# --> 481 return solve_func(self, *args, **kwargs)
#
# File ~\anaconda3\envs\diss\lib\site-packages\cvxpy\problems\problem.py:1016, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, **kwargs)
#    1014 end = time.time()
#    1015 self._solve_time = end - start
# -> 1016 self.unpack_results(solution, solving_chain, inverse_data)
#    1017 if verbose:
#    1018     print(_FOOTER)
#
# File ~\anaconda3\envs\diss\lib\site-packages\cvxpy\problems\problem.py:1341, in Problem.unpack_results(self, solution, chain, inverse_data)
#    1339     warnings.warn(INF_OR_UNB_MESSAGE)
#    1340 if solution.status in s.ERROR:
# -> 1341     raise error.SolverError(
#    1342             "Solver '%s' failed. " % chain.solver.name() +
#    1343             "Try another solver, or solve with verbose=True for more "
#    1344             "information.")
#    1346 self.unpack(solution)
#    1347 self._solver_stats = SolverStats(self._solution.attr,
#    1348                                  chain.solver.name())
#
# SolverError: Solver 'OSQP' failed. Try another solver, or solve with verbose=True for more information.

# %%
# Efficient frontiers for dfferent maximum leverages
fig, ax=plt.subplots()

for leverage_index, leverage in enumerate(leverage_range):
    plt.plot(portf_vol_l_ef[:, leverage_index],
            portf_rtn_l_ef[:, leverage_index],
            label=f'{leverage}')
    
ax.set(title='efficient Frontier for different Maximum Leverages',
       xlabel='Volatility',
       ylabel='Expected Returns')
ax.legend(title='Max leverage',
          bbox_to_anchor=(1,1))

# %%
# Plotting weight allocation per varying risk-aversion levels
fig, ax = plt.subplots(len_leverage, 1, sharex=True)

for ax_index in range(len_leverage):
    weights_df = pd.DataFrame (weights_ef[ax_index],
                               columns=assets,
                               index=np.round(gamma_range, 3))
    weights_df.plot(kind='bar',
                    stacked=True,
                    ax=ax[ax_index],
                    legend=None)
    ax[ax_index].set(ylabel=(f'max_leverage = {leverage_range[ax_index]}'
                             '/n weight'))
    
ax[len_leverage - 1].set(xlabel=r'$\gamma$')
ax[0].legend(bbox_to_anchor=(1,1))
ax[0].set_title('Weights allocation per risk-aversion level',
                fontsize=16)
# Out:
# Text(0.5, 1.0, 'Weights allocation per risk-aversion level')
